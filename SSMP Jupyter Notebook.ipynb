# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# ## **Salim Moncrieffe-Plentie**
# ##   Senior Analytics Executive (Current)

# %% [markdown]
# ### *I am interested in data science because I'm seeking a role that is more visualization based involving building dashboards in Python, Power BI or Data Studio. I believe it is necessary to have a good grounding in data science fundamentals to achieve this.*

# %% [markdown]
# ### **This code is for importing your libraries and outputing 1+1**

# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set(color_codes=True)

print(1+1)
# Out:
# 2

# %% [markdown]
# ***
#
# ### In the remainder of the notebook we will be covering the following:
#  * Defining your variables
#  * Plotting a basic graph
#  * A more complex plot
#
# ~More~ help with `Markdowns` can be found at [^1]
#
# [^1]: https://www.earthdatascience.org/courses/intro-to-earth-data-science/file-formats/use-text-files/format-text-with-markdown-jupyter-notebook/
#
# ***

# %% [markdown]
# ### 1. Defining your variables

# %%
a = [2,5]
b = [-2,5]
c = np.arange(0.0, 2.0, 0.01)
d = 1 + np.sin(2 * np.pi * c)

# %% [markdown]
# #### 2a. Plotting a basic graph

# %%
plt.plot(a,b)

# %% [markdown]
# #### 2b. A more complex plot

# %%
fig, ax = plt.subplots()
ax.plot(c, d)

ax.set(xlabel = 'Time (s)', ylabel = 'Watts (w)',
      title = 'A little bit more defined!')
ax.grid()
      
fig.savefig("first.png")
plt.show()
